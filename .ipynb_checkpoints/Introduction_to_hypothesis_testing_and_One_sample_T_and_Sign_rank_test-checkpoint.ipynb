# %% [markdown]
# ### Hypothesis Testing

# %% [markdown]
# Hypothesis testing is an act in statistics with which an analyst tests an assumption regarding a population parameter. It is used extensively to assess the plausibility of a hypothesis by using sample data. The assumptions made might be correct or it may not be. Data alone isn't interesting enough. It is the interpretation that we are really interested in

# %% [markdown]
# In research, there are two types of hypotheses: null and alternative. They work as a complementary pair, each stating that the other is wrong.
#
# **Null Hypothesis (H0)** –> This can be thought of as the implied hypothesis. “Null” meaning “nothing.”  This hypothesis states that there is no difference between groups or no relationship between variables. The null hypothesis is a presumption of status quo or no change.
#
# **Alternative Hypothesis (H1)** –> This is also known as the claim. This hypothesis should state what you expect the data to show, based on your research on the topic. This is your answer to your research question.

# %% [markdown]
# Example: Testing the Mean of a Population
#
# Scenario: A manufacturer claims that the average lifespan of their light bulbs is 1000 hours. A quality control engineer wants to test if this claim is accurate.
#
# Hypotheses:
#
# • **Null Hypothesis (𝐻0)**: The mean lifespan of the light bulbs is 1000 hours (μ=1000).
# • **Alternative Hypothesis (𝐻1)**: The mean lifespan of the light bulbs is not 1000 hours (𝜇≠1000).

# %% [markdown]
# Hypothesis testing can be set up in 3 different ways:
#
# 1. **Two-Tailed Test**
# • Null Hypothesis (𝐻0): The sample mean is equal to a specified population mean.
# • Alternative Hypothesis (H1): The sample mean is not equal to the specified population mean.
# $$ H0: μ=μ_{0} $$
# $$ H1: 𝜇≠𝜇_{0} $$
#
# Note: This test checks if the sample mean differs significantly from the specified population mean in either direction.
#
#
# 2. **Right-Tailed Test**
# • Null Hypothesis (H0): The sample mean is less than or equal to a specified population mean.
# • Alternative Hypothesis (H1): The sample mean is greater than the specified population mean.
# $$ H0: 𝜇≤𝜇_{0}  $$
# $$ H1:𝜇>𝜇_{0}   $$
#
# Note: This test determines if the sample mean is significantly greater than the specified population mean.
#
# 3. **Left-Tailed Test**
# Null Hypothesis (H0): The sample mean is greater than or equal to a specified population mean.
# Alternative Hypothesis (H1): The sample mean is less than the specified population mean.
# $$ H0: 𝜇≥𝜇_{0}    $$
# $$ H1: 𝜇<𝜇_{0}    $$

# %% [markdown]
# **Choose the Alpha (α) Level:**
#
# • The alpha level sets the acceptable risk of making a Type I error (rejecting the null hypothesis when it is actually true). It is typically set at 0.05 or 0.01.

# %% [markdown]
# **Determine the Test Statistic:**
#
# • Select the appropriate statistical test (e.g., t-test, ANOVA, chi-square test, etc.) that matches your data and hypothesis.
# This test statistic provides a mathematical formula to evaluate your data

# %% [markdown]
# **Calculate the Test Statistic and Find the p-value:**
#
# • Compute the test statistic based on your sample data.
# Use this statistic to calculate the p-value (the probability of observing your data if the null hypothesis is true).

# %% [markdown]
# **Make a Decision:**
#
# • Compare the p-value to the alpha level:
#     • If p-value ≤ α: Reject the null hypothesis. The data provide sufficient evidence to support the alternative hypothesis.
#     • If p-value > α: Fail to reject the null hypothesis. The data do not provide sufficient evidence to support the alternative hypothesis.

# %% [markdown]
# **Interpret the Results:**
#
# • If you reject the null hypothesis, interpret what the results mean in terms of practical significance or implications.
# • If you fail to reject the null hypothesis, conclude that the data do not show a statistically significant difference or relationship.

# %% [markdown]
# **Report the Findings:**
#
# • Present your findings along with the details of the statistical test used.
# • Explain the data analysis and results in a way that supports the accuracy and reliability of your findings.

# %% [markdown]
# ### Test for normality

# %% [markdown]
# Before running any hypothesis test, it's important to know which statistical method we should use. Statstical methods are divided in two parts :
#
# • Parametric statistical methods
#
# • Nonparametric statistical methods
#
# To know which one to use, normality tests must be done on our data. If our data have a known and specific distribution, such as the Gaussian distribution; parametric statistical methods must be used. On the contrary, if data are not Gaussian, nonparametric statistical methods should be used.
#
# There are two main ways to know if our data are Gaussian :
#
# 1. Graphical methods
#
# • Stem and leaf display
# • Histogram plot
# • QQ plot
#
# 2. Statistical methods
#
# • Shapiro test
# • D'Agostino and Pearson test
# • Anderson-Darling test
# • Kolmogorov-Smirnov test
#
# **Graphical methods** are mainly used for qualifying deviations from normality
#
# **Statistical methods** are mainly used for quantifying deviations from normality

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import stemgraphic
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from scipy import stats
import pylab
import numpy as np

# %%
df=pd.read_excel(r'datasets\statistic_data.xlsx', sheet_name="normal_data")

# %%
df.head()
# Out:
#    data
# 0    36
# 1    37
# 2    38
# 3    38
# 4    39

# %%
df.shape
# Out:
# (100, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   data    100 non-null    int64
# dtypes: int64(1)
# memory usage: 932.0 bytes

# %%
data=df['data']

# %% [markdown]
# ### Graphical methods

# %% [markdown]
# **Stem plot**

# %%
stemgraphic.stem_graphic(data, scale=2)
plt.show()

# %% [markdown]
# **Histogram**

# %%
sns.histplot(data)
plt.show()

# %%
sns.distplot(data)
plt.show()

# %%
sns.distplot(data, fit=stats.norm)
plt.show()

# %% [markdown]
# **QQ plot**

# %%
stats.probplot(data, dist='norm', plot=pylab)
pylab.show()

# %% [markdown]
# ### Statistical methods

# %% [markdown]
# **Shapiro Wilk test**

# %%
print(stats.shapiro(data))
# Out:
# ShapiroResult(statistic=0.992806613445282, pvalue=0.8761231303215027)

# %% [markdown]
# **Jarque-Bera test**

# %%
print(stats.jarque_bera(data))
# Out:
# SignificanceResult(statistic=0.47571834977004324, pvalue=0.7883136976444416)

# %% [markdown]
# According to the given information, since the p-value is greater than 0.05, 𝐻0 cannot be rejected. Therefore, it is accepted that the data follow a normal distribution.

# %% [markdown]
# ### One sample t-test

# %% [markdown]
# **If the data we have is greater than 120 or a normal distribution, we can apply the t test.**

# %% [markdown]
# **Example:** According to the American Health Association, a pregnant woman’s average blood pressure is 120 mm Hg. Collected 15 random samples from pregnant women to check whether the sample blood pressure differs from accepted standard blood pressure. Significance level:0.05
# [131, 115, 118, 120, 126, 137, 125, 116, 117, 122, 123, 128, 110, 124, 133]
#
# •  Null Hypothesis: H0: μ=120
# •  Alternative Hypothesis: H1: μ≠120
# •  α=0.05
# •  Degrees of freedom(df): 15 – 1 = 14

# %% [markdown]
# Calculate the critical value

# %% [markdown]
# ![o4.jpg](attachment:o4.jpg)

# %% [markdown]
# **$$ t_{critic}=2.145 $$**
#
# If the calculated t value is less than -2.145 or greater than 2.145, then reject the Null Hypothesis.

# %% [markdown]
# **Test Statistics**
# x̅ = 123
# μ0 = 120
# std=7.3

# %% [markdown]
# ![formula.jfif](attachment:formula.jfif)

# %% [markdown]
# $$ t_{statistics}=1.59 $$

# %% [markdown]
# ![ot2.png](attachment:ot2.png)

# %%
example=[131, 115, 118, 120, 126, 137, 125, 116, 117, 122, 123, 128, 110, 124, 133]

mean_value = np.mean(example)

print("Mean:",mean_value)

t_statistic, p_value=stats.ttest_1samp(example, 120, alternative='two-sided')

t_c=stats.t.ppf(q=1-.05/2,df=len(data)-1)

print(f't critic: {t_c}')

print("P Value:", p_value)

print("t-test Value:", t_statistic)

# 0.05 or 5% is significance level or alpha.

if p_value < 0.05:    

    print("Hypothesis rejected")

else:
    
    print("Hypothesis fail to rejected")
# Out:
# Mean: 123.0
# t critic: 1.9842169515086827
# P Value: 0.13521173980940243
# t-test Value: 1.585338409406782
# Hypothesis fail to rejected

# %% [markdown]
# **Interpret the results:** Compare t calc to t critical. In hypothesis testing, a critical value is a point on the test distribution compared to the test statistic to determine whether to reject the Null Hypothesis. The calculated t-statistic value is less than the critical value; hence we failed to reject Null Hypothesis.

# %%
print(len(data))
# Out:
# 100

# %% [markdown]
# The number of data is less than 120, but since it is a normal distribution, we can apply the t test.

# %% [markdown]
# H0 (null hypothesis): mu=60
# H1 (alternative hypotesis): mu!=60

# %%
t_statistic, p_value=stats.ttest_1samp(data, 60, alternative='two-sided')
print(f't statistic: {t_statistic}')

t_c=stats.t.ppf(q=1-.05/2,df=len(data)-1)
print(f't critic: {t_c}')
# Out:
# t statistic: -36.993122661656386
# t critic: 1.9842169515086827

# %% [markdown]
# Since t_statictic value is less than t_c value, t_statictic belongs to a rejection region. In this case, H0 is rejected.

# %% [markdown]
# Since we reject H0, a is either greater than 60 or less.

# %% [markdown]
# H0 (null hypothesis): mu>=60
# H1 (alternative hypotesis): mu<60

# %%
t_statistic, p_value=stats.ttest_1samp(data, 60, alternative='less')
print(f't statistic: {t_statistic}')

t_c=stats.t.ppf(q=.05,df=len(data)-1)
print(f't critic: {t_c}')
# Out:
# t statistic: -36.993122661656386
# t critic: -1.6603911559963902

# %% [markdown]
# Since t_statictic value is less than t_c value, t_statictic belongs to a rejection region. In this case, H0 is rejected. Since a is rejected, it appears that the mean is less than 60

# %% [markdown]
# ### Confidence Interval

# %% [markdown]
# **A confidence interval** is a range of values, derived from sample data, that is likely to contain the true value of a population parameter (such as a mean or proportion) with a certain level of confidence. It provides an estimate of how much uncertainty is associated with the sample statistic.

# %% [markdown]
# Example:
# If a researcher calculates a 95% confidence interval for the average height of a population and finds it to be [170cm,180cm], this means that there is a 95% chance that the true population mean height lies within that range.

# %% [markdown]
# ![CI-for-t.png](attachment:CI-for-t.png)

# %%
confidence_interval = stats.t.interval(
    confidence=0.95,        
    df=len(data)-1,      
    loc=np.mean(data),
    scale=stats.sem(data)
)

print(confidence_interval)
# Out:
# (44.72225690272161, 46.27774309727839)

# %%
df=pd.read_excel(r'datasets\statistic_data.xlsx', sheet_name="sign_rank")

# %%
df.head()
# Out:
#    data
# 0    21
# 1    18
# 2    11
# 3    14
# 4    10

# %%
data=df['data']

# %% [markdown]
# Since the number of data is less than 120, normality tests must be done.

# %%
sns.histplot(data)
plt.show()

# %%
t_statistic, p_value=stats.shapiro(data)
print('p_value:', '%.3f'%p_value)
# Out:
# p_value: 0.000

# %% [markdown]
# Since a value is less than 0.05, the distribution is not a normal distribution. The data number is not more than 120, nor is it a normal distribution. That's why I can't use the t-test. That's why we use the Wilcoxon Rank Sum test. This time we are testing the median, not the mean. Because in data with high outliers, we were interested in the median, not the mean.

# %% [markdown]
# ### Sign Rank test

# %% [markdown]
# **If the sample size is less than 25, this method is used.**

# %% [markdown]
# X=[4, 14, 25, 0, 18, 22, 15, 10, 3, 3, 4, 20, 10, 5, 30, 9]
# H0: mu=21
# H1: mu<21

# %% [markdown]
# $$ X=[4, 14, 25, 0, 18, 22, 15, 10, 3, 3, 4, 20, 10, 5, 30, 9] $$
#
# $$ X_{i}-median $$
#
# $$ X_{i}-median={[-17, -7, 4, -21, -3, 1, -6, -11, -18, -18, -17, -1, -11, -16, 9, -12]} $$
#
# $$ k^+=3 $$
#
# $$ k^-=13 $$
#
# $$ k=min(k^+, k^-)=min(13, 3)=3 $$

# %% [markdown]
# ![WhatsApp%20Image%202024-08-06%20at%2012.06.45.jpeg](attachment:WhatsApp%20Image%202024-08-06%20at%2012.06.45.jpeg)

# %% [markdown]
# n=16
# k=3
# p=0.011
# p<0.05, Ho reject

# %% [markdown]
# **If the sample size is ≥25, this method is used.**

# %% [markdown]
# $$ z=\frac{k-\frac{n}{2}}{\frac{\sqrt{n}}{2}} $$

# %% [markdown]
# **In the decision stage, since the hypothesis is one-tailed and formulated as '<', the left side of the curve is considered**

# %% [markdown]
# **Let's assume in the above example that**

# %% [markdown]
# $$ z=\frac{6-\frac{27}{2}}{\frac{\sqrt{27}}{2}}=-2.88 $$

# %% [markdown]
# p_value=0.002
# p_value<alpha
# H0 reject

# %% [markdown]
# ### Wilcoxon test

# %% [markdown]
# H0 (null hypothesis): mu=25
# H1 (alternative hypotesis): mu!=25

# %%
w, p = stats.wilcoxon(np.array(data)-25, alternative='two-sided')
print(w, p)
# Out:
# 63.0 0.021372318267822266

# %% [markdown]
# H0 is rejected because p value is less than 0.05. Then the median is either greater than 25 or less. We set up a new hypothesis test.

# %% [markdown]
# H0 (null hypothesis): mu=25
# H1 (alternative hypotesis): mu<25

# %%
w, p = stats.wilcoxon(np.array(data)-25, alternative='less')
print(w, p)
# Out:
# 63.0 0.010686159133911133

# %% [markdown]
# H0 is rejected because p value is less than 0.05. As can be understood then, the median is considered to be less than 25.

# %%
print('mean:', np.mean(data))
print('median:', np.median(data))
# Out:
# mean: 15.391304347826088
# median: 9.0

# %% [markdown]
# Data with outliers does not have a confidence interval
